# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 10
plt.rcParams["figure.figsize"] = (20, 10)

# %%
df = pd.read_csv('Data\\Tomato\\prepare\\data6.csv')

# %%
df
# Out:
#     Unnamed: 0         수집일  내부CO2(ppm)  내부습도(%)  외부온도(도)  내부온도(도)  \
# 0            0  2017-03-12      380.00    88.63     6.96    17.96
# 1            1  2017-03-19      379.46    93.13     7.88    17.92
# 2            2  2017-03-26      378.96    96.83     7.13    15.96
# 3            3  2017-04-02      380.00    93.79     8.54    18.00
# 4            4  2017-04-09      380.00    87.54    16.29    20.71
# ..         ...         ...         ...      ...      ...      ...
# 84          84  2022-05-04      582.21    78.79    15.43    17.54
# 85          85  2022-05-11      672.13    94.79    18.29    20.17
# 86          86  2022-05-18      621.50    89.08    20.33    21.13
# 87          87  2022-05-25      621.25    98.63    21.46    22.42
# 88          88  2022-06-08      529.25    99.92    17.67    18.92
#
#     내부질소(t ha-1)  내부인(t ha-1)  생장길이(cm)  열매수
# 0           4.96       332.54       193   13
# 1           5.65       381.02       190   13
# 2           3.02       176.58       178   19
# 3           5.26       332.28       168   13
# 4           2.99       166.58      2624   19
# ..           ...          ...       ...  ...
# 84          4.39       285.38       243   13
# 85          3.25       206.19       268   16
# 86          3.92       228.24       204   14
# 87          4.42       235.21       244   13
# 88          5.68       306.15       193   11
#
# [89 rows x 10 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#            수집일  내부CO2(ppm)  내부습도(%)  외부온도(도)  내부온도(도)  내부질소(t ha-1)  \
# 0   2017-03-12      380.00    88.63     6.96    17.96          4.96
# 1   2017-03-19      379.46    93.13     7.88    17.92          5.65
# 2   2017-03-26      378.96    96.83     7.13    15.96          3.02
# 3   2017-04-02      380.00    93.79     8.54    18.00          5.26
# 4   2017-04-09      380.00    87.54    16.29    20.71          2.99
# ..         ...         ...      ...      ...      ...           ...
# 84  2022-05-04      582.21    78.79    15.43    17.54          4.39
# 85  2022-05-11      672.13    94.79    18.29    20.17          3.25
# 86  2022-05-18      621.50    89.08    20.33    21.13          3.92
# 87  2022-05-25      621.25    98.63    21.46    22.42          4.42
# 88  2022-06-08      529.25    99.92    17.67    18.92          5.68
#
#     내부인(t ha-1)  생장길이(cm)  열매수
# 0        332.54       193   13
# 1        381.02       190   13
# 2        176.58       178   19
# 3        332.28       168   13
# 4        166.58      2624   19
# ..          ...       ...  ...
# 84       285.38       243   13
# 85       206.19       268   16
# 86       228.24       204   14
# 87       235.21       244   13
# 88       306.15       193   11
#
# [89 rows x 9 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

years=[2017, 2018, 2019, 2020, 2021, 2022]


x = df.index
y = df['생장길이(cm)']
z = df['열매수']

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z)
ax.set_xlabel('연도')
ax.set_ylabel('생장길이')
ax.set_zlabel('열매수')
ax.set_title('3차원 산점도')


plt.show()

# %%
# x값으로 인덱스(row)를 사용합니다.
x = df.index
y = df['생장길이(cm)']

# 산점도를 그립니다.
plt.scatter(x, y)
plt.xlabel('인덱스')
plt.ylabel('생장길이(cm)')
plt.title('산점도')
plt.show()

# %%
# x값으로 인덱스(row)를 사용합니다.
x = df.index
y = df['열매수']

# 산점도를 그립니다.
plt.scatter(x, y)
plt.xlabel('인덱스')
plt.ylabel('열매수(개)')
plt.title('산점도')
plt.show()
